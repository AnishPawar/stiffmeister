# %%
import pandas as pd

# %%
model = pd.Series(["Honda","BMW","Ford"])

# %%
year = pd.Series(["2000","2010","1990"])

# %%
df = pd.DataFrame({"Model":model,"Year":year})
df
# Out:
#    Model  Year
# 0  Honda  2000
# 1    BMW  2010
# 2   Ford  1990

# %%
car_sales_df = pd.read_csv("car-sales.csv")

# %%
car_sales_df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# car_sales_df.head()

# %%
car_sales_df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales_df.to_csv("exported.csv",index=False)

# %%
car_sales_df.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales_df.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales_df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales_df.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
    car_sales_df.mean(axis=0)
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_sales_df["Doors"].sum
# Out:
# <bound method Series.sum of 0    4
# 1    4
# 2    3
# 3    5
# 4    4
# 5    4
# 6    4
# 7    4
# 8    4
# 9    4
# Name: Doors, dtype: int64>

# %%
len(car_sales_df)
# Out:
# 10

# %%
car_sales_df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# # .loc gives index

# %%
model = pd.Series(["Honda","BMW","Ford","Ferrari","Lamborghini"],index=[5,3,1,4,4])

# %%
model.loc[4]
# Out:
# 4        Ferrari
# 4    Lamborghini
# dtype: object

# %% [markdown]
# # .iloc gives the position

# %%
model.iloc[4]
# Out:
# 'Lamborghini'

# %%
car_sales_df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales_df.iloc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
car_sales_df[car_sales_df['Make'] == "Toyota"]
# car_sales_df["Odometer (KM)"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales_df[car_sales_df.Make == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales_df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Crosstab
pd.crosstab(car_sales_df.Make,car_sales_df.Doors)
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# Groupby 
car_sales_df.groupby(['Make']).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
car_sales_df.Doors.plot()

# %%
car_sales_df.Doors.hist()

# %%
car_sales_df.Price = car_sales_df.Price.str.replace('[\$\,\.]','').astype(int)

# %%
car_sales_df.Price.plot()

# %% [markdown]
# # Manipulating Data

# %%
car_sales_df.Make.str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales_df.Make = car_sales_df.Make.str.lower()
car_sales_df
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
car_sales_missing = pd.read_csv('car-sales-missing-data.csv')

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing.Odometer.mean()
# Out:
# 92302.66666666667

# %%
car_sales_missing.Odometer.fillna(car_sales_missing.Odometer.mean(),inplace= True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing = car_sales_missing.dropna()
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
seats= pd.Series([5,6,7,5,5])

# %%
car_sales_df["Seats"] = seats

# %%
car_sales_df
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   400000    5.0
# 1   honda    Red          87899      4   500000    6.0
# 2  toyota   Blue          32549      3   700000    7.0
# 3     bmw  Black          11179      5  2200000    5.0
# 4  nissan  White         213095      4   350000    5.0
# 5  toyota  Green          99213      4   450000    NaN
# 6   honda   Blue          45698      4   750000    NaN
# 7   honda   Blue          54738      4   700000    NaN
# 8  toyota  White          60000      4   625000    NaN
# 9  nissan  White          31600      4   970000    NaN

# %%
car_sales_df["Seats"] = car_sales_df["Seats"].fillna(10)

# %%
car_sales_df
# Out:
#      Make Colour  Odometer (KM)  Doors    Price   Safe
# 5  toyota  Green      62008.125      4   450000  False
# 4  nissan  White     133184.375      4   350000   True
# 7   honda   Blue      34211.250      4   700000   True
# 9  nissan  White      19750.000      4   970000   True
# 1   honda    Red      54936.875      4   500000   True
# 3     bmw  Black       6986.875      5  2200000   True
# 0  toyota  White      93776.875      4   400000   True
# 8  toyota  White      37500.000      4   625000   True
# 6   honda   Blue      28561.250      4   750000   True
# 2  toyota   Blue      20343.125      3   700000   True

# %%
 car_sales_df = car_sales_df.drop("Seats",axis=1)

# %%
car_sales_df["Safe"] = [True,True,True,True,True,False,True,True,True,True]

# %%
# Sample Randomizes the data inside the sample size
car_sales_df = car_sales_df.sample(frac = 1)

# %%
# reset index 
# car_sales_df = car_sales_df.reset_index(drop = True)
# car_sales_df = car_sales_df.drop("level_0",axis = 1)

# %%
car_sales_df["Odometer (KM)"] = car_sales_df["Odometer (KM)"].apply(lambda x: x/1.6)
car_sales_df
# Out:
#      Make Colour  Odometer (KM)  Doors    Price   Safe
# 5  toyota  Green   38755.078125      4   450000  False
# 4  nissan  White   83240.234375      4   350000   True
# 7   honda   Blue   21382.031250      4   700000   True
# 9  nissan  White   12343.750000      4   970000   True
# 1   honda    Red   34335.546875      4   500000   True
# 3     bmw  Black    4366.796875      5  2200000   True
# 0  toyota  White   58610.546875      4   400000   True
# 8  toyota  White   23437.500000      4   625000   True
# 6   honda   Blue   17850.781250      4   750000   True
# 2  toyota   Blue   12714.453125      3   700000   True
